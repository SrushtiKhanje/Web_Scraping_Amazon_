# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.find("span", attrs={'class':'a-price aok-align-center reinventPricePriceToPayMargin priceToPay'}).find('span', attrs ={'class':'a-offscreen'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'class':'a-size-base dealBadgeSupportingText a-text-bold'}).find('span', attrs ={'class':'a-offscreen'}).string.strip()

        except:
            price = ""

    return price
    

    
# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count


# function to extract asin 
def get_asin(soup):
    try:
        asin_number = soup.find("div", attrs={'id':'detailBullets_feature_div'}).find('span', attrs ={'class':'a-text-bold'})

    except AttributeError:
        asin_number = ""	

    return asin_number

# function to extract description 
def get_product_description(soup):
    try:
        prod_description = soup.find("div", attrs={'id':'productDescription'}).string.strip()

    except AttributeError:
        prod_description = ""	

    return prod_description

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"Title":[], "Price":[], "Rating":[], "Reviews":[], "ASIN":[], 'Product Description':[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")
        
        # Function calls to display all necessary product information
        d['Title'].append(get_title(new_soup))
        d['Price'].append(get_price(new_soup))
        d['Rating'].append(get_rating(new_soup))
        d['Reviews'].append(get_review_count(new_soup))
        d['Product Description'].append(get_product_description(new_soup))
        d['ASIN'].append(get_asin(new_soup))


    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['Title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['Title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 Title Price  \
# 1   Urban Tribe Havana Basics 15.6" inch Laptop Ba...
# 3   Lavie Sport Chairman 20L Laptop Backpack for M...
# 7   Wesley Milestone 2.0 15.6 inch 30 L Casual Wat...
# 8   Wesley Milestone 2.0 15.6 inch 30 L Casual Wat...
# 9   ADISA 15.6 inch Laptop Backpack Office Bag Col...
# 20  DEIN KLEIDER Nylon Sling Cross Body Travel Off...
# 22  Northzone Casual Waterproof Laptop Backpack/Of...
# 24  RL Swisslook Polyster Bange Series 45L USB Tra...
# 27  Wenger 17.5" ScanSmart Laptop Backpack, 30 Lit...
# 30  Kuber Industries Handcrafted Embroidered Clutc...
# 39  Blue Tree Boy's and Girl's Plush Soft Spiderma...
# 46  AirCase C34 13 Inch/ 14 Inch/15.6 Inch Premium...
# 50  Half Moon Large 37L Laptop Bag Backpack for me...
# 55  Bennett Mystic 15.6 inch Laptop Shoulder Messe...
# 57  HEROZ Unisex Hammer Nylon 45 L Travel Laptop B...
# 59  FATMUG Unisex-Adult Laptop Bag Convertible Bac...
# ...
